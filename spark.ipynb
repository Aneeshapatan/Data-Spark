# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\DELL\Downloads\Sales.csv", encoding='ISO-8859-1')
df.dropna(subset=['Delivery Date'], inplace=True)
print(len(df))
# Convert 'Order Date' and 'Delivery Date' to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce', format='%m/%d/%Y')
df['Delivery Date'] = pd.to_datetime(df['Delivery Date'], errors='coerce', format='%m/%d/%Y')
df.dropna(inplace=True)
print(len(df))
# Filter the rows where 'Delivery Date' is earlier than 'Order Date'
df = df[df['Delivery Date'] >= df['Order Date']]

# Handle duplicates 
df.drop_duplicates(inplace=True)

# reset the index after dropping rows
df.reset_index(drop=True, inplace=True)


# Saving the file 
df.to_csv(r"C:\Users\DELL\OneDrive\문서\mini project 1\Cleaned_Sales.csv", encoding='ISO-8859-1', index=False)
df
# Out:
# 13165
# 13165
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366001          1 2016-01-01    2016-01-13      1269051
# 1            366001          2 2016-01-01    2016-01-13      1269051
# 2            366002          1 2016-01-01    2016-01-12       266019
# 3            366002          2 2016-01-01    2016-01-12       266019
# 4            366002          3 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 13160       2243029          6 2021-02-20    2021-02-27       887764
# 13161       2243031          1 2021-02-20    2021-02-24       511229
# 13162       2243032          1 2021-02-20    2021-02-23       331277
# 13163       2243032          2 2021-02-20    2021-02-23       331277
# 13164       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0             0        1048         2           USD
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13165 entries, 0 to 13164
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   13165 non-null  int64
#  1   Line Item      13165 non-null  int64
#  2   Order Date     13165 non-null  datetime64[ns]
#  3   Delivery Date  13165 non-null  datetime64[ns]
#  4   CustomerKey    13165 non-null  int64
#  5   StoreKey       13165 non-null  int64
#  6   ProductKey     13165 non-null  int64
#  7   Quantity       13165 non-null  int64
#  8   Currency Code  13165 non-null  object
# dtypes: datetime64[ns](2), int64(6), object(1)
# memory usage: 925.8+ KB

# %%
import pandas as pd
df1=pd.read_csv(r"C:\Users\DELL\Downloads\Stores.csv")
df1.dropna(subset=['Open Date'], inplace=True)
# Convert 'Open Date'  to datetime format
df1['Open Date'] = pd.to_datetime(df1['Open Date'], errors='coerce', format='%m/%d/%Y')
# Handle duplicates 
df1.drop_duplicates(inplace=True)
# reset the index after dropping rows
df1.reset_index(drop=True, inplace=True)
# Saving the file 
df1.to_csv(r"C:\Users\DELL\OneDrive\문서\mini project 1\Cleaned_Store.csv", encoding='ISO-8859-1', index=False)
df1
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 2.7+ KB

# %%
import pandas as pd
df2 = pd.read_csv(r"C:\Users\DELL\Downloads\Customers.csv", encoding='ISO-8859-1')
df2.dropna(subset=['Birthday'], inplace=True)
# Convert 'Birthday'  to datetime format
df2['Birthday'] = pd.to_datetime(df2['Birthday'], errors='coerce', format='%m/%d/%Y')

# Handle duplicates 
df2.drop_duplicates(inplace=True)
# reset the index after dropping rows
df2.reset_index(drop=True, inplace=True)
# Saving the file 
df2.to_csv(r"C:\Users\DELL\OneDrive\문서\mini project 1\Customers_Store.csv", encoding='ISO-8859-1', index=False)
df2
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
import pandas as pd
df3 = pd.read_csv(r"C:\Users\DELL\Downloads\Data_Dictionary.csv", encoding='ISO-8859-1')
# Saving the file
df3.to_csv(r"C:\Users\DELL\OneDrive\문서\mini project 1\dictionarydata_Store.csv", encoding='ISO-8859-1', index=False)
df3
# Out:
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# ...

# %%
import pandas as pd
df4 = pd.read_csv(r"C:\Users\DELL\Downloads\Exchange_Rates.csv", encoding='ISO-8859-1')
df4.dropna(subset=['Date'], inplace=True)
# Convert 'Birthday'  to datetime format
df4['Date'] = pd.to_datetime(df4['Date'], errors='coerce', format='%m/%d/%Y')

# Handle duplicates 
df4.drop_duplicates(inplace=True)
# reset the index after dropping rows
df4.reset_index(drop=True, inplace=True)
# Saving the file 
df4.to_csv(r"C:\Users\DELL\OneDrive\문서\mini project 1\Exchange_Store.csv", encoding='ISO-8859-1', index=False)
df4
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
import pandas as pd
df5=pd.read_csv(r"C:\Users\DELL\Downloads\Products.csv")
# Remove dollar sign, commas, and strip any trailing or leading spaces
df5['Unit Cost USD'] = df5['Unit Cost USD'].str.replace('$', '').str.replace(',', '').str.strip()
df5['Unit Price USD'] = df5['Unit Price USD'].str.replace('$', '').str.replace(',', '').str.strip()
# Convert the cleaned strings to floats
df5['Unit Cost USD'] = df5['Unit Cost USD'].astype(float)
df5['Unit Price USD'] = df5['Unit Price USD'].astype(float)
# Saving the file 
df5.to_csv(r"C:\Users\DELL\OneDrive\문서\mini project 1\products_Store.csv", encoding='ISO-8859-1', index=False)
df5
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13165 entries, 0 to 13164
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   13165 non-null  int64
#  1   Line Item      13165 non-null  int64
#  2   Order Date     13165 non-null  datetime64[ns]
#  3   Delivery Date  13165 non-null  datetime64[ns]
#  4   CustomerKey    13165 non-null  int64
#  5   StoreKey       13165 non-null  int64
#  6   ProductKey     13165 non-null  int64
#  7   Quantity       13165 non-null  int64
#  8   Currency Code  13165 non-null  object
# dtypes: datetime64[ns](2), int64(6), object(1)
# memory usage: 925.8+ KB

# %%
print(df5.isnull().sum())
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
print(df5.dtypes)
# Out:
# ProductKey          int64
# Product Name       object
# Brand              object
# Color              object
# Unit Cost USD     float64
# Unit Price USD    float64
# SubcategoryKey      int64
# Subcategory        object
# CategoryKey         int64
# Category           object
# dtype: object
